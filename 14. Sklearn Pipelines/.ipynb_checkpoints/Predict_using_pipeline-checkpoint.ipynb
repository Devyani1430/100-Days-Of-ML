# %%
import pickle
import numpy as np

# %%
pipe=pickle.load(open('pipe.pkl','rb'))

# %%
# Assume User Input 

test_input=np.array([1, 'female', 31.0, 0, 0, 11.5, 'C'],dtype=object).reshape(1,7)

# %%
pipe.predict(test_input)
# Out:
# C:\Users\Admin\miniconda3\envs\campusx\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# C:\Users\Admin\miniconda3\envs\campusx\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# array([1])
