# %%
import numpy as np
import pandas as pd

import scipy.stats as stats

import matplotlib.pyplot as plt
import seaborn as sbs

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier

from sklearn.preprocessing import FunctionTransformer
from sklearn.compose import ColumnTransformer

# %%
df=pd.read_csv("train.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df=pd.read_csv("train.csv",usecols=["Age","Fare","Survived"])

# %%
df.head()
# Out:
#    Survived   Age     Fare
# 0         0  22.0   7.2500
# 1         1  38.0  71.2833
# 2         1  26.0   7.9250
# 3         1  35.0  53.1000
# 4         0  35.0   8.0500

# %%
df.isnull().sum()
# Out:
# Survived      0
# Age         177
# Fare          0
# dtype: int64

# %%
df["Age"].fillna(df["Age"].mean(),inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12124\2595122914.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df["Age"].fillna(df["Age"].mean(),inplace=True)
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.699118
# 889    26.000000
# 890    32.000000
# Name: Age, Length: 891, dtype: float64

# %%
df.isnull().sum()
# Out:
# Survived      0
# Age         177
# Fare          0
# dtype: int64

# %%
X=df.iloc[:,1:3]
Y=df.iloc[:,0]

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
plt.figure(figsize=(14,4))

plt.subplot(121)
sbs.distplot(X_train["Age"])
plt.title("Age PDF")

plt.subplot(122)
stats.probplot(X_train["Age"],dist="norm",plot=plt)
plt.title("Age QQ plot")

plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12124\4194183962.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sbs.distplot(X_train["Age"])

# %%
plt.figure(figsize=(14,4))

plt.subplot(121)
sbs.distplot(X_train["Fare"])
plt.title("Fare PDF")

plt.subplot(122)
stats.probplot(X_train["Fare"],dist="norm",plot=plt)
plt.title("Fare QQ plot")

plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12124\3363055257.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sbs.distplot(X_train["Fare"])

# %%
clf1=LogisticRegression()
clf2=DecisionTreeClassifier()

# %%
clf1.fit(X_train,Y_train)
clf2.fit(X_train,Y_train)

y_pred1=clf1.predict(X_test)
y_pred2=clf2.predict(X_test)

accuracy1=accuracy_score(y_pred1,Y_test)
accuracy2=accuracy_score(y_pred2,Y_test)
print("Logistic Regression Accuracy Score is",accuracy1)
print("Decision Treee Accuracy Score is",accuracy2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 clf1.fit(X_train,Y_train)
#       2 clf2.fit(X_train,Y_train)
#       3
#       4 y_pred1=clf1.predict(X_test)
#
# File ~\miniconda3\envs\campusx\Lib\site-packages\sklearn\base.py:1403, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1393     estimator._validate_params()
#    1395 with (
#    1396     config_context(
#    1397         skip_parameter_validation=(
#    (...)   1401     callback_management_context(estimator),
#    1402 ):
# -> 1403     return fit_method(estimator, *args, **kwargs)
#
# File ~\miniconda3\envs\campusx\Lib\site-packages\sklearn\linear_model\_logistic.py:1459, in LogisticRegression.fit(self, X, y, sample_weight)
#    1456 if self.n_jobs is not None:
#    1457     warnings.warn(msg, category=FutureWarning)
# -> 1459 X, y = validate_data(
#    1460     self,
#    1461     X,
#    1462     y,
#    1463     accept_sparse="csr",
#    1464     dtype=[xp.float64, xp.float32],
#    1465     order="C",
#    1466     accept_large_sparse=solver not in ["liblinear", "sag", "saga"],
#    1467 )
#    1468 n_features = X.shape[1]
#    1469 check_classification_targets(y)
#
# File ~\miniconda3\envs\campusx\Lib\site-packages\sklearn\utils\validation.py:3055, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    3053         y = check_array(y, input_name="y", **check_y_params)
#    3054     else:
# -> 3055         X, y = check_X_y(X, y, **check_params)
#    3056     out = X, y
#    3058 if not no_val_X and check_params.get("ensure_2d", True):
#
# File ~\miniconda3\envs\campusx\Lib\site-packages\sklearn\utils\validation.py:1327, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, ensure_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1322         estimator_name = _check_estimator_name(estimator)
#    1323     raise ValueError(
#    1324         f"{estimator_name} requires y to be passed, but the target y is None"
#    1325     )
# -> 1327 X = check_array(
#    1328     X,
#    1329     accept_sparse=accept_sparse,
#    1330     accept_large_sparse=accept_large_sparse,
#    1331     dtype=dtype,
#    1332     order=order,
#    1333     copy=copy,
#    1334     force_writeable=force_writeable,
#    1335     ensure_all_finite=ensure_all_finite,
#    1336     ensure_2d=ensure_2d,
#    1337     allow_nd=allow_nd,
#    1338     ensure_min_samples=ensure_min_samples,
#    1339     ensure_min_features=ensure_min_features,
#    1340     estimator=estimator,
#    1341     input_name="X",
#    1342 )
#    1344 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1346 check_consistent_length(X, y)
#
# File ~\miniconda3\envs\campusx\Lib\site-packages\sklearn\utils\validation.py:1087, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1081     raise ValueError(
#    1082         f"Found array with dim {array.ndim},"
#    1083         f" while dim <= 2 is required{context}."
#    1084     )
#    1086 if ensure_all_finite:
# -> 1087     _assert_all_finite(
#    1088         array,
#    1089         input_name=input_name,
#    1090         estimator_name=estimator_name,
#    1091         allow_nan=ensure_all_finite == "allow-nan",
#    1092     )
#    1094 if copy:
#    1095     if _is_numpy_namespace(xp):
#    1096         # only make a copy if `array` and `array_orig` may share memory`
#
# File ~\miniconda3\envs\campusx\Lib\site-packages\sklearn\utils\validation.py:137, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     134 if first_pass_isfinite:
#     135     return
# --> 137 _assert_all_finite_element_wise(
#     138     X,
#     139     xp=xp,
#     140     allow_nan=allow_nan,
#     141     msg_dtype=msg_dtype,
#     142     estimator_name=estimator_name,
#     143     input_name=input_name,
#     144 )
#
# File ~\miniconda3\envs\campusx\Lib\site-packages\sklearn\utils\validation.py:186, in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     169 if estimator_name and input_name == "X" and has_nan_error:
#     170     # Improve the error message on how to handle missing values in
#     171     # scikit-learn.
#     172     msg_err += (
#     173         f"\n{estimator_name} does not accept missing values"
#     174         " encoded as NaN natively. For supervised learning, you might want"
#    (...)    184         "#estimators-that-handle-nan-values"
#     185     )
# --> 186 raise ValueError(msg_err)
#
# ValueError: Input X contains NaN.
# LogisticRegression does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values

# %%
trf1=FunctionTransformer(func=np.log1p)

# %%
X_train_transformed=trf1.fit_transform(X_train)
X_test_transformed=trf1.fit_transform(X_test)

# %%
clf1=LogisticRegression()
clf2=DecisionTreeClassifier()

# %%
clf1.fit(X_train_transformed,Y_train)
clf2.fit(X_train_transformed,Y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 clf1.fit(X_train_transformed,Y_train)
#       2 clf2.fit(X_train_transformed,Y_train)
#
# File ~\miniconda3\envs\campusx\Lib\site-packages\sklearn\base.py:1403, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1393     estimator._validate_params()
#    1395 with (
#    1396     config_context(
#    1397         skip_parameter_validation=(
#    (...)   1401     callback_management_context(estimator),
#    1402 ):
# -> 1403     return fit_method(estimator, *args, **kwargs)
#
# File ~\miniconda3\envs\campusx\Lib\site-packages\sklearn\linear_model\_logistic.py:1459, in LogisticRegression.fit(self, X, y, sample_weight)
#    1456 if self.n_jobs is not None:
#    1457     warnings.warn(msg, category=FutureWarning)
# -> 1459 X, y = validate_data(
#    1460     self,
#    1461     X,
#    1462     y,
#    1463     accept_sparse="csr",
#    1464     dtype=[xp.float64, xp.float32],
#    1465     order="C",
#    1466     accept_large_sparse=solver not in ["liblinear", "sag", "saga"],
#    1467 )
#    1468 n_features = X.shape[1]
#    1469 check_classification_targets(y)
#
# File ~\miniconda3\envs\campusx\Lib\site-packages\sklearn\utils\validation.py:3055, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    3053         y = check_array(y, input_name="y", **check_y_params)
#    3054     else:
# -> 3055         X, y = check_X_y(X, y, **check_params)
#    3056     out = X, y
#    3058 if not no_val_X and check_params.get("ensure_2d", True):
#
# File ~\miniconda3\envs\campusx\Lib\site-packages\sklearn\utils\validation.py:1327, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, ensure_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1322         estimator_name = _check_estimator_name(estimator)
#    1323     raise ValueError(
#    1324         f"{estimator_name} requires y to be passed, but the target y is None"
#    1325     )
# -> 1327 X = check_array(
#    1328     X,
#    1329     accept_sparse=accept_sparse,
#    1330     accept_large_sparse=accept_large_sparse,
#    1331     dtype=dtype,
#    1332     order=order,
#    1333     copy=copy,
#    1334     force_writeable=force_writeable,
#    1335     ensure_all_finite=ensure_all_finite,
#    1336     ensure_2d=ensure_2d,
#    1337     allow_nd=allow_nd,
#    1338     ensure_min_samples=ensure_min_samples,
#    1339     ensure_min_features=ensure_min_features,
#    1340     estimator=estimator,
#    1341     input_name="X",
#    1342 )
#    1344 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1346 check_consistent_length(X, y)
#
# File ~\miniconda3\envs\campusx\Lib\site-packages\sklearn\utils\validation.py:1087, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1081     raise ValueError(
#    1082         f"Found array with dim {array.ndim},"
#    1083         f" while dim <= 2 is required{context}."
#    1084     )
#    1086 if ensure_all_finite:
# -> 1087     _assert_all_finite(
#    1088         array,
#    1089         input_name=input_name,
#    1090         estimator_name=estimator_name,
#    1091         allow_nan=ensure_all_finite == "allow-nan",
#    1092     )
#    1094 if copy:
#    1095     if _is_numpy_namespace(xp):
#    1096         # only make a copy if `array` and `array_orig` may share memory`
#
# File ~\miniconda3\envs\campusx\Lib\site-packages\sklearn\utils\validation.py:137, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     134 if first_pass_isfinite:
#     135     return
# --> 137 _assert_all_finite_element_wise(
#     138     X,
#     139     xp=xp,
#     140     allow_nan=allow_nan,
#     141     msg_dtype=msg_dtype,
#     142     estimator_name=estimator_name,
#     143     input_name=input_name,
#     144 )
#
# File ~\miniconda3\envs\campusx\Lib\site-packages\sklearn\utils\validation.py:186, in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     169 if estimator_name and input_name == "X" and has_nan_error:
#     170     # Improve the error message on how to handle missing values in
#     171     # scikit-learn.
#     172     msg_err += (
#     173         f"\n{estimator_name} does not accept missing values"
#     174         " encoded as NaN natively. For supervised learning, you might want"
#    (...)    184         "#estimators-that-handle-nan-values"
#     185     )
# --> 186 raise ValueError(msg_err)
#
# ValueError: Input X contains NaN.
# LogisticRegression does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values

# %%
y_pred=clf1.predict(X_test_transformed)
y_pred1=clf2.predict(X_test_transformed)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 y_pred=clf1.predict(X_test_transformed)
#       2 y_pred1=clf2.predict(X_test_transformed)
#
# File ~\miniconda3\envs\campusx\Lib\site-packages\sklearn\linear_model\_base.py:414, in LinearClassifierMixin.predict(self, X)
#     412 check_same_namespace(X, self, attribute="coef_", method="predict")
#     413 xp, _, device_ = get_namespace_and_device(X)
# --> 414 scores = self.decision_function(X)
#     415 if len(scores.shape) == 1:
#     416     indices = xp.astype(scores > 0, indexing_dtype(xp))
#
# File ~\miniconda3\envs\campusx\Lib\site-packages\sklearn\linear_model\_base.py:389, in LinearClassifierMixin.decision_function(self, X)
#     386 xp, _ = get_namespace(X)
#     387 check_same_namespace(X, self, attribute="coef_", method="decision_function")
# --> 389 X = validate_data(self, X, accept_sparse="csr", reset=False)
#     390 coef_T = self.coef_.T if self.coef_.ndim == 2 else self.coef_
#     391 scores = safe_sparse_dot(X, coef_T, dense_output=True) + self.intercept_
#
# File ~\miniconda3\envs\campusx\Lib\site-packages\sklearn\utils\validation.py:3038, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    3036         out = X, y
#    3037 elif not no_val_X and no_val_y:
# -> 3038     out = check_array(X, input_name="X", **check_params)
#    3039 elif no_val_X and not no_val_y:
#    3040     out = _check_y(y, **check_params)
#
# File ~\miniconda3\envs\campusx\Lib\site-packages\sklearn\utils\validation.py:1087, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1081     raise ValueError(
#    1082         f"Found array with dim {array.ndim},"
#    1083         f" while dim <= 2 is required{context}."
#    1084     )
#    1086 if ensure_all_finite:
# -> 1087     _assert_all_finite(
#    1088         array,
#    1089         input_name=input_name,
#    1090         estimator_name=estimator_name,
#    1091         allow_nan=ensure_all_finite == "allow-nan",
#    1092     )
#    1094 if copy:
#    1095     if _is_numpy_namespace(xp):
#    1096         # only make a copy if `array` and `array_orig` may share memory`
#
# File ~\miniconda3\envs\campusx\Lib\site-packages\sklearn\utils\validation.py:137, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     134 if first_pass_isfinite:
#     135     return
# --> 137 _assert_all_finite_element_wise(
#     138     X,
#     139     xp=xp,
#     140     allow_nan=allow_nan,
#     141     msg_dtype=msg_dtype,
#     142     estimator_name=estimator_name,
#     143     input_name=input_name,
#     144 )
#
# File ~\miniconda3\envs\campusx\Lib\site-packages\sklearn\utils\validation.py:186, in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     169 if estimator_name and input_name == "X" and has_nan_error:
#     170     # Improve the error message on how to handle missing values in
#     171     # scikit-learn.
#     172     msg_err += (
#     173         f"\n{estimator_name} does not accept missing values"
#     174         " encoded as NaN natively. For supervised learning, you might want"
#    (...)    184         "#estimators-that-handle-nan-values"
#     185     )
# --> 186 raise ValueError(msg_err)
#
# ValueError: Input X contains NaN.
# LogisticRegression does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values

# %%
print("Logistic regression Accuracy:",accuracy_score(y_pred,Y_test))
print("Decision Tree Accuracy:",accuracy_score(y_pred1,Y_test))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 print("Logistic regression Accuracy:",accuracy_score(y_pred,Y_test))
#       2 print("Decision Tree Accuracy:",accuracy_score(y_pred1,Y_test))
#
# NameError: name 'y_pred' is not defined

# %%
X_transformed=trf1.fit_transform(X)

clf_1=LogisticRegression()
clf_2=DecisionTreeClassifier()

print("Accuracy_1",np.mean(cross_val_score(clf_1,X_transformed,Y,scoring="accuracy",cv=10)))
print("Accuracy_2",np.mean(cross_val_score(clf_2,X_transformed,Y,scoring="accuracy",cv=10)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 6
#       2
#       3 clf_1=LogisticRegression()
#       4 clf_2=DecisionTreeClassifier()
#       5
# ----> 6 print("Accuracy_1",np.mean(cross_val_score(clf_1,X_transformed,Y,scoring="accuracy",cv=10)))
#       7 print("Accuracy_2",np.mean(cross_val_score(clf_2,X_transformed,Y,scoring="accuracy",cv=10)))
#
# File ~\miniconda3\envs\campusx\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File ~\miniconda3\envs\campusx\Lib\site-packages\sklearn\model_selection\_validation.py:650, in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, params, pre_dispatch, error_score)
#     647 # To ensure multimetric format is not supported
#     648 scorer = check_scoring(estimator, scoring=scoring)
# --> 650 cv_results = cross_validate(
#     651     estimator=estimator,
#     652     X=X,
#     653     y=y,
#     654     groups=groups,
#     655     scoring={"score": scorer},
#     656     cv=cv,
#     657     n_jobs=n_jobs,
#     658     verbose=verbose,
#     659     params=params,
#     660     pre_dispatch=pre_dispatch,
#     661     error_score=error_score,
#     662 )
#     663 return cv_results["test_score"]
#
# File ~\miniconda3\envs\campusx\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File ~\miniconda3\envs\campusx\Lib\site-packages\sklearn\model_selection\_validation.py:392, in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, params, pre_dispatch, return_train_score, return_estimator, return_indices, error_score)
#     371 parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
#     372 results = parallel(
#     373     delayed(_fit_and_score)(
#     374         clone(estimator),
#    (...)    389     for train, test in indices
#     390 )
# --> 392 _warn_or_raise_about_fit_failures(results, error_score)
#     394 # For callable scoring, the return type is only know after calling. If the
#     395 # return type is a dictionary, the error scores can now be inserted with
#     396 # the correct key.
#     397 if callable(scoring):
#
# File ~\miniconda3\envs\campusx\Lib\site-packages\sklearn\model_selection\_validation.py:478, in _warn_or_raise_about_fit_failures(results, error_score)
#     471 if num_failed_fits == num_fits:
#     472     all_fits_failed_message = (
#     473         f"\nAll the {num_fits} fits failed.\n"
#     474         "It is very likely that your model is misconfigured.\n"
#     475         "You can try to debug the error by setting error_score='raise'.\n\n"
#     476         f"Below are more details about the failures:\n{fit_errors_summary}"
#     477     )
# --> 478     raise ValueError(all_fits_failed_message)
#     480 else:
#     481     some_fits_failed_message = (
#     482         f"\n{num_failed_fits} fits failed out of a total of {num_fits}.\n"
#     483         "The score on these train-test partitions for these parameters"
#    (...)    487         f"Below are more details about the failures:\n{fit_errors_summary}"
#     488     )
#
# ValueError:
# All the 10 fits failed.
# It is very likely that your model is misconfigured.
# You can try to debug the error by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Admin\miniconda3\envs\campusx\Lib\site-packages\sklearn\model_selection\_validation.py", line 856, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#     ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\miniconda3\envs\campusx\Lib\site-packages\sklearn\base.py", line 1403, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "C:\Users\Admin\miniconda3\envs\campusx\Lib\site-packages\sklearn\linear_model\_logistic.py", line 1459, in fit
#     X, y = validate_data(
#            ~~~~~~~~~~~~~^
#         self,
#         ^^^^^
#     ...<5 lines>...
#         accept_large_sparse=solver not in ["liblinear", "sag", "saga"],
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\Users\Admin\miniconda3\envs\campusx\Lib\site-packages\sklearn\utils\validation.py", line 3055, in validate_data
#     X, y = check_X_y(X, y, **check_params)
#            ~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\miniconda3\envs\campusx\Lib\site-packages\sklearn\utils\validation.py", line 1327, in check_X_y
#     X = check_array(
#         X,
#     ...<12 lines>...
#         input_name="X",
#     )
#   File "C:\Users\Admin\miniconda3\envs\campusx\Lib\site-packages\sklearn\utils\validation.py", line 1087, in check_array
#     _assert_all_finite(
#     ~~~~~~~~~~~~~~~~~~^
#         array,
#         ^^^^^^
#     ...<2 lines>...
#         allow_nan=ensure_all_finite == "allow-nan",
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\Users\Admin\miniconda3\envs\campusx\Lib\site-packages\sklearn\utils\validation.py", line 137, in _assert_all_finite
#     _assert_all_finite_element_wise(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         X,
#         ^^
#     ...<4 lines>...
#         input_name=input_name,
#         ^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\Users\Admin\miniconda3\envs\campusx\Lib\site-packages\sklearn\utils\validation.py", line 186, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input X contains NaN.
# LogisticRegression does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values

# %%
plt.figure(figsize=(14,5))

plt.subplot(121)
stats.probplot(X_train["Fare"],dist='norm',plot=plt)
plt.title("Fare Before Transformation")

plt.subplot(122)
stats.probplot(X_train_transformed["Fare"],dist='norm',plot=plt)
plt.title("Fare After Transformation")
plt.show()

# %%
plt.figure(figsize=(14,4))

plt.subplot(121)
stats.probplot(X_train["Age"],dist='norm',plot=plt)
plt.title("Age Before Transformation")

plt.subplot(122)
stats.probplot(X_train_transformed["Age"],dist='norm',plot=plt)
plt.title("Age After Transformation")

plt.show()

# %%
trf2=ColumnTransformer([('log',FunctionTransformer(np.log1p),['Fare'])],remainder="passthrough")

X_train_transformed2=trf2.fit_transform(X_train)
X_test_transformed2=trf2.fit_transform(X_test)

# %%
clf_a=LogisticRegression()
clf_b=DecisionTreeClassifier()

clf_a.fit(X_train_transformed2,Y_train)
clf_b.fit(X_train_transformed2,Y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 4
#       1 clf_a=LogisticRegression()
#       2 clf_b=DecisionTreeClassifier()
#       3
# ----> 4 clf_a.fit(X_train_transformed2,Y_train)
#       5 clf_b.fit(X_train_transformed2,Y_train)
#
# File ~\miniconda3\envs\campusx\Lib\site-packages\sklearn\base.py:1403, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1393     estimator._validate_params()
#    1395 with (
#    1396     config_context(
#    1397         skip_parameter_validation=(
#    (...)   1401     callback_management_context(estimator),
#    1402 ):
# -> 1403     return fit_method(estimator, *args, **kwargs)
#
# File ~\miniconda3\envs\campusx\Lib\site-packages\sklearn\linear_model\_logistic.py:1459, in LogisticRegression.fit(self, X, y, sample_weight)
#    1456 if self.n_jobs is not None:
#    1457     warnings.warn(msg, category=FutureWarning)
# -> 1459 X, y = validate_data(
#    1460     self,
#    1461     X,
#    1462     y,
#    1463     accept_sparse="csr",
#    1464     dtype=[xp.float64, xp.float32],
#    1465     order="C",
#    1466     accept_large_sparse=solver not in ["liblinear", "sag", "saga"],
#    1467 )
#    1468 n_features = X.shape[1]
#    1469 check_classification_targets(y)
#
# File ~\miniconda3\envs\campusx\Lib\site-packages\sklearn\utils\validation.py:3055, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    3053         y = check_array(y, input_name="y", **check_y_params)
#    3054     else:
# -> 3055         X, y = check_X_y(X, y, **check_params)
#    3056     out = X, y
#    3058 if not no_val_X and check_params.get("ensure_2d", True):
#
# File ~\miniconda3\envs\campusx\Lib\site-packages\sklearn\utils\validation.py:1327, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, ensure_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1322         estimator_name = _check_estimator_name(estimator)
#    1323     raise ValueError(
#    1324         f"{estimator_name} requires y to be passed, but the target y is None"
#    1325     )
# -> 1327 X = check_array(
#    1328     X,
#    1329     accept_sparse=accept_sparse,
#    1330     accept_large_sparse=accept_large_sparse,
#    1331     dtype=dtype,
#    1332     order=order,
#    1333     copy=copy,
#    1334     force_writeable=force_writeable,
#    1335     ensure_all_finite=ensure_all_finite,
#    1336     ensure_2d=ensure_2d,
#    1337     allow_nd=allow_nd,
#    1338     ensure_min_samples=ensure_min_samples,
#    1339     ensure_min_features=ensure_min_features,
#    1340     estimator=estimator,
#    1341     input_name="X",
#    1342 )
#    1344 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1346 check_consistent_length(X, y)
#
# File ~\miniconda3\envs\campusx\Lib\site-packages\sklearn\utils\validation.py:1087, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1081     raise ValueError(
#    1082         f"Found array with dim {array.ndim},"
#    1083         f" while dim <= 2 is required{context}."
#    1084     )
#    1086 if ensure_all_finite:
# -> 1087     _assert_all_finite(
#    1088         array,
#    1089         input_name=input_name,
#    1090         estimator_name=estimator_name,
#    1091         allow_nan=ensure_all_finite == "allow-nan",
#    1092     )
#    1094 if copy:
#    1095     if _is_numpy_namespace(xp):
#    1096         # only make a copy if `array` and `array_orig` may share memory`
#
# File ~\miniconda3\envs\campusx\Lib\site-packages\sklearn\utils\validation.py:137, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     134 if first_pass_isfinite:
#     135     return
# --> 137 _assert_all_finite_element_wise(
#     138     X,
#     139     xp=xp,
#     140     allow_nan=allow_nan,
#     141     msg_dtype=msg_dtype,
#     142     estimator_name=estimator_name,
#     143     input_name=input_name,
#     144 )
#
# File ~\miniconda3\envs\campusx\Lib\site-packages\sklearn\utils\validation.py:186, in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     169 if estimator_name and input_name == "X" and has_nan_error:
#     170     # Improve the error message on how to handle missing values in
#     171     # scikit-learn.
#     172     msg_err += (
#     173         f"\n{estimator_name} does not accept missing values"
#     174         " encoded as NaN natively. For supervised learning, you might want"
#    (...)    184         "#estimators-that-handle-nan-values"
#     185     )
# --> 186 raise ValueError(msg_err)
#
# ValueError: Input X contains NaN.
# LogisticRegression does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values

# %%
y_prediction=clf_a.predict(X_test_transformed2)
y_prediction1=clf_b.predict(X_test_transformed2)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 y_prediction=clf_a.predict(X_test_transformed2)
#       2 y_prediction1=clf_b.predict(X_test_transformed2)
#
# File ~\miniconda3\envs\campusx\Lib\site-packages\sklearn\linear_model\_base.py:414, in LinearClassifierMixin.predict(self, X)
#     412 check_same_namespace(X, self, attribute="coef_", method="predict")
#     413 xp, _, device_ = get_namespace_and_device(X)
# --> 414 scores = self.decision_function(X)
#     415 if len(scores.shape) == 1:
#     416     indices = xp.astype(scores > 0, indexing_dtype(xp))
#
# File ~\miniconda3\envs\campusx\Lib\site-packages\sklearn\linear_model\_base.py:385, in LinearClassifierMixin.decision_function(self, X)
#     366 def decision_function(self, X):
#     367     """
#     368     Predict confidence scores for samples.
#     369
#    (...)    383         this class would be predicted.
#     384     """
# --> 385     check_is_fitted(self)
#     386     xp, _ = get_namespace(X)
#     387     check_same_namespace(X, self, attribute="coef_", method="decision_function")
#
# File ~\miniconda3\envs\campusx\Lib\site-packages\sklearn\utils\validation.py:1718, in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1715     return
#    1717 if not _is_fitted(estimator, attributes, all_or_any):
# -> 1718     raise NotFittedError(msg % {"name": type(estimator).__name__})
#
# NotFittedError: This LogisticRegression instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.

# %%
print("Accuracy 1:",accuracy_score(y_prediction,Y_test))
print("Accuracy 2:",accuracy_score(y_prediction1,Y_test))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 print("Accuracy 1:",accuracy_score(y_prediction,Y_test))
#       2 print("Accuracy 2:",accuracy_score(y_prediction1,Y_test))
#
# NameError: name 'y_prediction' is not defined

# %%
X_transformed1=trf2.fit_transform(X)

CLF=LogisticRegression()
CLF2=DecisionTreeClassifier()

print("Accuracy 1:",cross_val_score(CLF,X_transformed1,Y,scoring="accuracy",cv=10))
print("accuracy 2:",cross_val_score(CLF2,X_transformed1,Y,scoring="accuracy",cv=10))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 6
#       2
#       3 CLF=LogisticRegression()
#       4 CLF2=DecisionTreeClassifier()
#       5
# ----> 6 print("Accuracy 1:",cross_val_score(CLF,X_transformed1,Y,scoring="accuracy",cv=10))
#       7 print("accuracy 2:",cross_val_score(CLF2,X_transformed1,Y,scoring="accuracy",cv=10))
#
# File ~\miniconda3\envs\campusx\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File ~\miniconda3\envs\campusx\Lib\site-packages\sklearn\model_selection\_validation.py:650, in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, params, pre_dispatch, error_score)
#     647 # To ensure multimetric format is not supported
#     648 scorer = check_scoring(estimator, scoring=scoring)
# --> 650 cv_results = cross_validate(
#     651     estimator=estimator,
#     652     X=X,
#     653     y=y,
#     654     groups=groups,
#     655     scoring={"score": scorer},
#     656     cv=cv,
#     657     n_jobs=n_jobs,
#     658     verbose=verbose,
#     659     params=params,
#     660     pre_dispatch=pre_dispatch,
#     661     error_score=error_score,
#     662 )
#     663 return cv_results["test_score"]
#
# File ~\miniconda3\envs\campusx\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File ~\miniconda3\envs\campusx\Lib\site-packages\sklearn\model_selection\_validation.py:392, in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, params, pre_dispatch, return_train_score, return_estimator, return_indices, error_score)
#     371 parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
#     372 results = parallel(
#     373     delayed(_fit_and_score)(
#     374         clone(estimator),
#    (...)    389     for train, test in indices
#     390 )
# --> 392 _warn_or_raise_about_fit_failures(results, error_score)
#     394 # For callable scoring, the return type is only know after calling. If the
#     395 # return type is a dictionary, the error scores can now be inserted with
#     396 # the correct key.
#     397 if callable(scoring):
#
# File ~\miniconda3\envs\campusx\Lib\site-packages\sklearn\model_selection\_validation.py:478, in _warn_or_raise_about_fit_failures(results, error_score)
#     471 if num_failed_fits == num_fits:
#     472     all_fits_failed_message = (
#     473         f"\nAll the {num_fits} fits failed.\n"
#     474         "It is very likely that your model is misconfigured.\n"
#     475         "You can try to debug the error by setting error_score='raise'.\n\n"
#     476         f"Below are more details about the failures:\n{fit_errors_summary}"
#     477     )
# --> 478     raise ValueError(all_fits_failed_message)
#     480 else:
#     481     some_fits_failed_message = (
#     482         f"\n{num_failed_fits} fits failed out of a total of {num_fits}.\n"
#     483         "The score on these train-test partitions for these parameters"
#    (...)    487         f"Below are more details about the failures:\n{fit_errors_summary}"
#     488     )
#
# ValueError:
# All the 10 fits failed.
# It is very likely that your model is misconfigured.
# You can try to debug the error by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Admin\miniconda3\envs\campusx\Lib\site-packages\sklearn\model_selection\_validation.py", line 856, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#     ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\miniconda3\envs\campusx\Lib\site-packages\sklearn\base.py", line 1403, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "C:\Users\Admin\miniconda3\envs\campusx\Lib\site-packages\sklearn\linear_model\_logistic.py", line 1459, in fit
#     X, y = validate_data(
#            ~~~~~~~~~~~~~^
#         self,
#         ^^^^^
#     ...<5 lines>...
#         accept_large_sparse=solver not in ["liblinear", "sag", "saga"],
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\Users\Admin\miniconda3\envs\campusx\Lib\site-packages\sklearn\utils\validation.py", line 3055, in validate_data
#     X, y = check_X_y(X, y, **check_params)
#            ~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\miniconda3\envs\campusx\Lib\site-packages\sklearn\utils\validation.py", line 1327, in check_X_y
#     X = check_array(
#         X,
#     ...<12 lines>...
#         input_name="X",
#     )
#   File "C:\Users\Admin\miniconda3\envs\campusx\Lib\site-packages\sklearn\utils\validation.py", line 1087, in check_array
#     _assert_all_finite(
#     ~~~~~~~~~~~~~~~~~~^
#         array,
#         ^^^^^^
#     ...<2 lines>...
#         allow_nan=ensure_all_finite == "allow-nan",
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\Users\Admin\miniconda3\envs\campusx\Lib\site-packages\sklearn\utils\validation.py", line 137, in _assert_all_finite
#     _assert_all_finite_element_wise(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         X,
#         ^^
#     ...<4 lines>...
#         input_name=input_name,
#         ^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\Users\Admin\miniconda3\envs\campusx\Lib\site-packages\sklearn\utils\validation.py", line 186, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input X contains NaN.
# LogisticRegression does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values

# %%
X_transformed1=trf1.fit_transform(X)

clfA=LogisticRegression()
clfB=DecisionTreeClassifier()

print("Accuracy_1",np.mean(cross_val_score(clfA,X_transformed1,Y,scoring="accuracy",cv=10)))
print("Accuracy_2",np.mean(cross_val_score(clfB,X_transformed1,Y,scoring="accuracy",cv=10)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 6
#       2
#       3 clfA=LogisticRegression()
#       4 clfB=DecisionTreeClassifier()
#       5
# ----> 6 print("Accuracy_1",np.mean(cross_val_score(clfA,X_transformed1,Y,scoring="accuracy",cv=10)))
#       7 print("Accuracy_2",np.mean(cross_val_score(clfB,X_transformed1,Y,scoring="accuracy",cv=10)))
#
# File ~\miniconda3\envs\campusx\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File ~\miniconda3\envs\campusx\Lib\site-packages\sklearn\model_selection\_validation.py:650, in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, params, pre_dispatch, error_score)
#     647 # To ensure multimetric format is not supported
#     648 scorer = check_scoring(estimator, scoring=scoring)
# --> 650 cv_results = cross_validate(
#     651     estimator=estimator,
#     652     X=X,
#     653     y=y,
#     654     groups=groups,
#     655     scoring={"score": scorer},
#     656     cv=cv,
#     657     n_jobs=n_jobs,
#     658     verbose=verbose,
#     659     params=params,
#     660     pre_dispatch=pre_dispatch,
#     661     error_score=error_score,
#     662 )
#     663 return cv_results["test_score"]
#
# File ~\miniconda3\envs\campusx\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File ~\miniconda3\envs\campusx\Lib\site-packages\sklearn\model_selection\_validation.py:392, in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, params, pre_dispatch, return_train_score, return_estimator, return_indices, error_score)
#     371 parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
#     372 results = parallel(
#     373     delayed(_fit_and_score)(
#     374         clone(estimator),
#    (...)    389     for train, test in indices
#     390 )
# --> 392 _warn_or_raise_about_fit_failures(results, error_score)
#     394 # For callable scoring, the return type is only know after calling. If the
#     395 # return type is a dictionary, the error scores can now be inserted with
#     396 # the correct key.
#     397 if callable(scoring):
#
# File ~\miniconda3\envs\campusx\Lib\site-packages\sklearn\model_selection\_validation.py:478, in _warn_or_raise_about_fit_failures(results, error_score)
#     471 if num_failed_fits == num_fits:
#     472     all_fits_failed_message = (
#     473         f"\nAll the {num_fits} fits failed.\n"
#     474         "It is very likely that your model is misconfigured.\n"
#     475         "You can try to debug the error by setting error_score='raise'.\n\n"
#     476         f"Below are more details about the failures:\n{fit_errors_summary}"
#     477     )
# --> 478     raise ValueError(all_fits_failed_message)
#     480 else:
#     481     some_fits_failed_message = (
#     482         f"\n{num_failed_fits} fits failed out of a total of {num_fits}.\n"
#     483         "The score on these train-test partitions for these parameters"
#    (...)    487         f"Below are more details about the failures:\n{fit_errors_summary}"
#     488     )
#
# ValueError:
# All the 10 fits failed.
# It is very likely that your model is misconfigured.
# You can try to debug the error by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Admin\miniconda3\envs\campusx\Lib\site-packages\sklearn\model_selection\_validation.py", line 856, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#     ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\miniconda3\envs\campusx\Lib\site-packages\sklearn\base.py", line 1403, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "C:\Users\Admin\miniconda3\envs\campusx\Lib\site-packages\sklearn\linear_model\_logistic.py", line 1459, in fit
#     X, y = validate_data(
#            ~~~~~~~~~~~~~^
#         self,
#         ^^^^^
#     ...<5 lines>...
#         accept_large_sparse=solver not in ["liblinear", "sag", "saga"],
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\Users\Admin\miniconda3\envs\campusx\Lib\site-packages\sklearn\utils\validation.py", line 3055, in validate_data
#     X, y = check_X_y(X, y, **check_params)
#            ~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\miniconda3\envs\campusx\Lib\site-packages\sklearn\utils\validation.py", line 1327, in check_X_y
#     X = check_array(
#         X,
#     ...<12 lines>...
#         input_name="X",
#     )
#   File "C:\Users\Admin\miniconda3\envs\campusx\Lib\site-packages\sklearn\utils\validation.py", line 1087, in check_array
#     _assert_all_finite(
#     ~~~~~~~~~~~~~~~~~~^
#         array,
#         ^^^^^^
#     ...<2 lines>...
#         allow_nan=ensure_all_finite == "allow-nan",
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\Users\Admin\miniconda3\envs\campusx\Lib\site-packages\sklearn\utils\validation.py", line 137, in _assert_all_finite
#     _assert_all_finite_element_wise(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         X,
#         ^^
#     ...<4 lines>...
#         input_name=input_name,
#         ^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\Users\Admin\miniconda3\envs\campusx\Lib\site-packages\sklearn\utils\validation.py", line 186, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input X contains NaN.
# LogisticRegression does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values

# %%
def apply_transform(transform):
    X = df.iloc[:,1:3]
    y = df.iloc[:,0]
    
    trf = ColumnTransformer([('log',FunctionTransformer(transform),['Fare'])],remainder='passthrough')
    
    X_trans = trf.fit_transform(X)
    
    clf = LogisticRegression()
    
    print("Accuracy",np.mean(cross_val_score(clf,X_trans,y,scoring='accuracy',cv=10)))
    
    plt.figure(figsize=(14,4))

    plt.subplot(121)
    stats.probplot(X['Fare'], dist="norm", plot=plt)
    plt.title('Fare Before Transform')

    plt.subplot(122)
    stats.probplot(X_trans[:,0], dist="norm", plot=plt)
    plt.title('Fare After Transform')

    plt.show()

# %%
apply_transform(np)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 apply_transform(np)
#
# Cell In[32], line 7, in apply_transform(transform)
#       3     y = df.iloc[:,0]
#       4
#       5     trf = ColumnTransformer([('log',FunctionTransformer(transform),['Fare'])],remainder='passthrough')
#       6
# ----> 7     X_trans = trf.fit_transform(X)
#       8
#       9     clf = LogisticRegression()
#      10
#
# File ~\miniconda3\envs\campusx\Lib\site-packages\sklearn\utils\_set_output.py:319, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     317 @wraps(f)
#     318 def wrapped(self, X, *args, **kwargs):
# --> 319     data_to_wrap = f(self, X, *args, **kwargs)
#     320     if isinstance(data_to_wrap, tuple):
#     321         # only wrap the first output for cross decomposition
#     322         return_tuple = (
#     323             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     324             *data_to_wrap[1:],
#     325         )
#
# File ~\miniconda3\envs\campusx\Lib\site-packages\sklearn\base.py:1403, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1393     estimator._validate_params()
#    1395 with (
#    1396     config_context(
#    1397         skip_parameter_validation=(
#    (...)   1401     callback_management_context(estimator),
#    1402 ):
# -> 1403     return fit_method(estimator, *args, **kwargs)
#
# File ~\miniconda3\envs\campusx\Lib\site-packages\sklearn\compose\_column_transformer.py:979, in ColumnTransformer.fit_transform(self, X, y, **params)
#     976 else:
#     977     routed_params = self._get_empty_routing()
# --> 979 result = self._call_func_on_transformers(
#     980     X,
#     981     y,
#     982     _fit_transform_one,
#     983     column_as_labels=False,
#     984     routed_params=routed_params,
#     985 )
#     987 if not result:
#     988     self._update_fitted_transformers([])
#
# File ~\miniconda3\envs\campusx\Lib\site-packages\sklearn\compose\_column_transformer.py:880, in ColumnTransformer._call_func_on_transformers(self, X, y, func, column_as_labels, routed_params)
#     876         else:  # func is _transform_one
#     877             extra_args = {}
#     878         jobs.append(
#     879             delayed(func)(
# --> 880                 transformer=clone(trans) if not fitted else trans,
#     881                 X=_safe_indexing(X, columns, axis=1),
#     882                 y=y,
#     883                 weight=weight,
#     884                 **extra_args,
#     885                 params=routed_params[name],
#     886             )
#     887         )
#     889     return Parallel(n_jobs=self.n_jobs)(jobs)
#     891 except ValueError as e:
#
# File ~\miniconda3\envs\campusx\Lib\site-packages\sklearn\base.py:96, in clone(estimator, safe)
#      47 """Construct a new unfitted estimator with the same parameters.
#      48
#      49 Clone does a deep copy of the model in an estimator
#    (...)     93 False
#      94 """
#      95 if hasattr(estimator, "__sklearn_clone__") and not inspect.isclass(estimator):
# ---> 96     return estimator.__sklearn_clone__()
#      97 return _clone_parametrized(estimator, safe=safe)
#
# File ~\miniconda3\envs\campusx\Lib\site-packages\sklearn\base.py:445, in BaseEstimator.__sklearn_clone__(self)
#     444 def __sklearn_clone__(self):
# --> 445     return _clone_parametrized(self)
#
# File ~\miniconda3\envs\campusx\Lib\site-packages\sklearn\base.py:129, in _clone_parametrized(estimator, safe)
#     127 new_object_params = estimator.get_params(deep=False)
#     128 for name, param in new_object_params.items():
# --> 129     new_object_params[name] = clone(param, safe=False)
#     131 new_object = klass(**new_object_params)
#     132 try:
#
# File ~\miniconda3\envs\campusx\Lib\site-packages\sklearn\base.py:97, in clone(estimator, safe)
#      95 if hasattr(estimator, "__sklearn_clone__") and not inspect.isclass(estimator):
#      96     return estimator.__sklearn_clone__()
# ---> 97 return _clone_parametrized(estimator, safe=safe)
#
# File ~\miniconda3\envs\campusx\Lib\site-packages\sklearn\base.py:110, in _clone_parametrized(estimator, safe)
#     108 elif not hasattr(estimator, "get_params") or isinstance(estimator, type):
#     109     if not safe:
# --> 110         return copy.deepcopy(estimator)
#     111     else:
#     112         if isinstance(estimator, type):
#
# File ~\miniconda3\envs\campusx\Lib\copy.py:146, in deepcopy(x, memo, _nil)
#     144 reductor = getattr(x, "__reduce_ex__", None)
#     145 if reductor is not None:
# --> 146     rv = reductor(4)
#     147 else:
#     148     reductor = getattr(x, "__reduce__", None)
#
# TypeError: cannot pickle 'module' object
