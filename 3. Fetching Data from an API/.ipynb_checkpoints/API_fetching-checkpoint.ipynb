# %%
import pandas as pd

# %%
import requests

# to create http rqst

# %%
response = requests.get("https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1")

# %%
response.json()['results']
# Out:
# [{'adult': False,
#   'backdrop_path': '/ezbrL1dMymKQZw7mDEWa2ZTzN7d.jpg',
#   'genre_ids': [16, 28, 12, 14],
#   'id': 980431,
#   'title': 'Avatar Aang: The Last Airbender',
#   'original_language': 'en',
#   'original_title': 'Avatar Aang: The Last Airbender',
#   'overview': "Avatar Aang, the world's last Airbender, learns of an ancient power that could save his culture from extinction. With the help of his friends, he embarks on a global quest to find it before it falls into the wrong hands and threatens to upend the peace they sacrificed everything to achieve.",
#   'popularity': 110.9348,
#   'poster_path': '/3sgnSfNT27Bx5O5ukr7B26mhEQq.jpg',
#   'release_date': '2026-07-24',
#   'softcore': False,
#   'video': False,
#   'vote_average': 9.227,
#   'vote_count': 897},
#  {'adult': False,
#   'backdrop_path': '/iCML6fBe3X0y06P33bM7dyYXPKZ.jpg',
#   'genre_ids': [35, 10749],
#   'id': 1632181,
#   'title': 'Accidental Partners',
#   'original_language': 'es',
# ...

# %%
pd.DataFrame(response.json()['results']).head(2)
# Out:
#    adult                     backdrop_path         genre_ids       id  \
# 0  False  /ezbrL1dMymKQZw7mDEWa2ZTzN7d.jpg  [16, 28, 12, 14]   980431
# 1  False  /iCML6fBe3X0y06P33bM7dyYXPKZ.jpg       [35, 10749]  1632181
#
#                              title original_language  \
# 0  Avatar Aang: The Last Airbender                en
# 1              Accidental Partners                es
#
#                     original_title  \
# 0  Avatar Aang: The Last Airbender
# 1             Socias por accidente
#
#                                             overview  popularity  \
# 0  Avatar Aang, the world's last Airbender, learn...    110.9348
# 1  Two women discover they were both scammed by t...     24.8184
#
#                         poster_path release_date  softcore  video  \
# 0  /3sgnSfNT27Bx5O5ukr7B26mhEQq.jpg   2026-07-24     False  False
# 1  /j0CIVzeR7hRAPBPGR54qDZoOQpp.jpg   2026-03-12     False  False
#
#    vote_average  vote_count
# 0         9.227         897
# ...

# %%
pd.DataFrame(response.json()['results']).head()[['id','title','popularity','release_date','vote_average','vote_count']]
# Out:
#         id                                           title  popularity  \
# 0   980431                 Avatar Aang: The Last Airbender    110.9348
# 1  1632181                             Accidental Partners     24.8184
# 2  1007757                                         Swapped     50.5290
# 3      278                        The Shawshank Redemption     88.7998
# 4  1311031  Demon Slayer: Kimetsu no Yaiba Infinity Castle     92.4348
#
#   release_date  vote_average  vote_count
# 0   2026-07-24         9.227         897
# 1   2026-03-12         8.900         354
# 2   2026-05-01         8.881        2111
# 3   1994-09-23         8.728       31074
# 4   2025-07-18         8.734        1886

# %%
df = pd.DataFrame(response.json()['results'])[['id','title','popularity','release_date','vote_average','vote_count']]

# %%
df.head()
# Out:
#         id                                           title  popularity  \
# 0   980431                 Avatar Aang: The Last Airbender    110.9348
# 1  1632181                             Accidental Partners     24.8184
# 2  1007757                                         Swapped     50.5290
# 3      278                        The Shawshank Redemption     88.7998
# 4  1311031  Demon Slayer: Kimetsu no Yaiba Infinity Castle     92.4348
#
#   release_date  vote_average  vote_count
# 0   2026-07-24         9.227         897
# 1   2026-03-12         8.900         354
# 2   2026-05-01         8.881        2111
# 3   1994-09-23         8.728       31074
# 4   2025-07-18         8.734        1886

# %%
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1, 429):
    
    # Make the API requests
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
    
    # Check if the request was successful (status code 200)
    if response.status_code == 200:
        
        # Extract relevant data from the response
        temp_df = pd.DataFrame(response.json()['results'])[['id', 'title', 'overview', 'release_date', 'popularity', 'vote_average', 'vote_count']]
        
        # Append the data to the main DataFrame
        df = pd.concat([df, temp_df], ignore_index=True)
    else:
        print(f"Failed to retrieve data for page {i}")

# %%
df.shape
# Out:
# (18560, 7)

# %%
df.to_csv('movies.csv')
